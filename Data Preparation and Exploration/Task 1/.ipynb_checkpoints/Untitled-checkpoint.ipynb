# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Employee Turnover Dataset.csv")

# %%
df.shape
# Out:
# (10199, 16)

# %%
df.duplicated().sum()
# Out:
# 99

# %%
df.isna().sum()
# Out:
# EmployeeNumber                     0
# Age                                0
# Tenure                             0
# Turnover                           0
# HourlyRate                         0
# HoursWeekly                        0
# CompensationType                   0
# AnnualSalary                       0
# DrivingCommuterDistance            0
# JobRoleArea                        0
# Gender                             0
# MaritalStatus                      0
# NumCompaniesPreviouslyWorked     665
# AnnualProfessionalDevHrs        1969
# PaycheckMethod                     0
# TextMessageOptIn                2266
# dtype: int64

# %%
print(df.dtypes)
# Out:
# EmployeeNumber                    int64
# Age                               int64
# Tenure                            int64
# Turnover                         object
# HourlyRate                       object
# HoursWeekly                       int64
# CompensationType                 object
# AnnualSalary                    float64
# DrivingCommuterDistance           int64
# JobRoleArea                      object
# Gender                           object
# MaritalStatus                    object
# NumCompaniesPreviouslyWorked    float64
# AnnualProfessionalDevHrs        float64
# PaycheckMethod                   object
# TextMessageOptIn                 object
# dtype: object

# %%
plt.figure(figsize=(12,6))
plt.scatter(df.index, df['HoursWeekly'], color='red')
plt.title('Outliers')
plt.xlabel('Index')
plt.ylabel('HourlyRate')
plt.xticks(rotation=90)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
df[df['PaycheckMethod'].str.contains('mail', case=False, na=False)]
# Out:
#        EmployeeNumber  Age  Tenure Turnover HourlyRate   HoursWeekly  \
# 0                   1   28       6      Yes     $24.37            40
# 1                   2   33       2      Yes     $24.37            40
# 2                   3   22       1       No     $22.52            40
# 3                   4   23       1       No     $22.52            40
# 4                   5   40       6       No     $88.77            40
# ...               ...  ...     ...      ...         ...          ...
# 10194              95   48      13      Yes     $85.40            40
# 10195              96   54      17       No     $85.40            40
# 10196              97   44       6       No     $71.90            40
# 10197              98   58      19       No     $71.90            40
# 10198              99   48      17      Yes     $71.33            40
#
#       CompensationType  AnnualSalary  DrivingCommuterDistance  \
# 0               Salary       50689.6                       89
# ...

# %%
for col in df.columns:
    print(f"\nColumn: {col}")
    print(df[col].unique())
# Out:
# Column: EmployeeNumber
# [    1     2     3 ... 10098 10099 10100]
#
# Column: Age
# [28 33 22 23 40 45 34 37 24 30 38 47 55 59 29 35 44 54 36 32 41 56 21 27
#  50 31 46 48 39 57 52 53 58 49 42 60 43 61 26 51 25]
#
# Column: Tenure
# [ 6  2  1 16  9  3  8  4 20 10  7 15  5 18 17 14 13 19 12 11]
#
# Column: Turnover
# ['Yes' 'No']
#
# Column: HourlyRate
# ['$24.37 ' '$22.52 ' '$88.77 ' ... '$30.86 ' '$95.07 ' '$93.05 ']
#
# Column: HoursWeekly
# [40]
#
# Column: CompensationType
# ['Salary']
#
# Column: AnnualSalary
# [ 50689.6  46841.6 284641.6 ... 337745.6 164902.4 333544. ]
#
# Column: DrivingCommuterDistance
# [  89   35   12    0   76   15    2   36   60   14   75    5  910   28
#    -4   33   79   50   13   57   82    4   42   -5   64   -8   77    1
#    24   67   41   62   47   -7   31   32   56   22   51   58   34   37
#    16   26   74  -10   -2   84   44   61   87   46   52   73   53   85
#    66   80   55  950   70   17  250  -12   43   49   81   86   -3   48
# ...

# %%
df2 = df.drop_duplicates()

# %%
df2.shape
# Out:
# (10100, 16)

# %%
df2.isnull().any(axis=1)
# Out:
# 0        False
# 1        False
# 2        False
# 3         True
# 4         True
#          ...
# 10095    False
# 10096    False
# 10097     True
# 10098    False
# 10099     True
# Length: 10100, dtype: bool

# %%
invalid_values = df2[(df2['DrivingCommuterDistance'] < 0)]
display (invalid_values)
# Out:
#        EmployeeNumber  Age  Tenure Turnover HourlyRate   HoursWeekly  \
# 30                 31   30       1       No     $24.50            40
# 31                 32   34       2       No     $24.50            40
# 54                 55   44      16       No     $31.30            40
# 55                 56   50       8       No     $31.30            40
# 64                 65   30       3      Yes     $29.49            40
# ...               ...  ...     ...      ...         ...          ...
# 10029           10030   44       5       No     $92.48            40
# 10039           10040   61      18       No     $71.91            40
# 10041           10042   61      14      Yes     $33.25            40
# 10096           10097   33       9      Yes     $23.28            40
# 10098           10099   50      12       No     $32.22            40
#
#       CompensationType  AnnualSalary  DrivingCommuterDistance  \
# 30              Salary       50960.0                       -4
# ...

# %%
invalid_values2 = df2[(df2['AnnualSalary'] < 0)]
display (invalid_values2)
# Out:
#       EmployeeNumber  Age  Tenure Turnover HourlyRate   HoursWeekly  \
# 54                55   44      16       No     $31.30            40
# 55                56   50       8       No     $31.30            40
# 64                65   30       3      Yes     $29.49            40
# 65                66   32       5      Yes     $29.49            40
# 541              542   37       7       No     $31.72            40
# 605              606   47       9       No     $32.58            40
# 658              659   30       3      Yes     $30.06            40
# 863              864   37       7       No     $30.99            40
# 1015            1016   40       9      Yes     $31.73            40
# 1320            1321   36      10      Yes     $32.60            40
# 1424            1425   31       8       No     $30.48            40
# 1549            1550   40       1      Yes     $31.85            40
# 1607            1608   32       3       No     $30.56            40
# ...

# %%
invalid_values.count()
# Out:
# EmployeeNumber                  1343
# Age                             1343
# Tenure                          1343
# Turnover                        1343
# HourlyRate                      1343
# HoursWeekly                     1343
# CompensationType                1343
# AnnualSalary                    1343
# DrivingCommuterDistance         1343
# JobRoleArea                     1343
# Gender                          1343
# MaritalStatus                   1343
# NumCompaniesPreviouslyWorked    1256
# AnnualProfessionalDevHrs        1071
# PaycheckMethod                  1343
# TextMessageOptIn                1074
# dtype: int64

# %%
df3 = df2.dropna()

# %%
df3.shape
# Out:
# (5917, 16)

# %%
df3.loc[:, 'DrivingCommuterDistance'] = df3['DrivingCommuterDistance'].abs()

# %%
invalid_values = df3[(df3['DrivingCommuterDistance'] < 0)]
display (invalid_values)
# Out:
# Empty DataFrame
# Columns: [EmployeeNumber, Age, Tenure, Turnover, HourlyRate , HoursWeekly, CompensationType, AnnualSalary, DrivingCommuterDistance, JobRoleArea, Gender, MaritalStatus, NumCompaniesPreviouslyWorked, AnnualProfessionalDevHrs, PaycheckMethod, TextMessageOptIn]
# Index: []

# %%
df3.loc[:, 'AnnualSalary'] = df3['AnnualSalary'].abs()

# %%
invalid_values2 = df3[(df3['AnnualSalary'] < 0)]
display (invalid_values2)
# Out:
# Empty DataFrame
# Columns: [EmployeeNumber, Age, Tenure, Turnover, HourlyRate , HoursWeekly, CompensationType, AnnualSalary, DrivingCommuterDistance, JobRoleArea, Gender, MaritalStatus, NumCompaniesPreviouslyWorked, AnnualProfessionalDevHrs, PaycheckMethod, TextMessageOptIn]
# Index: []

# %%
df4 = df3[df3['HoursWeekly'] == 40]
df4.shape
# Out:
# (5917, 16)

# %%
print(df4.dtypes)
# Out:
# EmployeeNumber                    int64
# Age                               int64
# Tenure                            int64
# Turnover                         object
# HourlyRate                       object
# HoursWeekly                       int64
# CompensationType                 object
# AnnualSalary                    float64
# DrivingCommuterDistance           int64
# JobRoleArea                      object
# Gender                           object
# MaritalStatus                    object
# NumCompaniesPreviouslyWorked    float64
# AnnualProfessionalDevHrs        float64
# PaycheckMethod                   object
# TextMessageOptIn                 object
# dtype: object

# %%
df4.loc[df4['PaycheckMethod'].str.contains('mail', case=False, na=False), 'PaycheckMethod'] = 'Mail Check'
df4.loc[df4['PaycheckMethod'].str.contains('direct', case=False, na=False), 'PaycheckMethod'] = 'Direct Deposit'

# %%
df4['PaycheckMethod'].unique()
# Out:
# array(['Mail Check', 'Direct Deposit'], dtype=object)
