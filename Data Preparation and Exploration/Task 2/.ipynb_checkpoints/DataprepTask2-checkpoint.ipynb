# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('Health Insurance Dataset Dataset.xlsx')

# %%
display (df)
# Out:
#        age     sex     bmi  children smoker     region      charges Level  \
# 0     19.0  female  27.900       0.0    yes  southwest    16884.924     B
# 1     18.0    male  33.770       1.0     no  southeast    1725.5523     C
# 2     28.0    male  33.000       3.0     no  southeast     4449.462     B
# 3     33.0    male  22.705       0.0     no  northwest  21984.47061     A
# 4     32.0    male  28.880       0.0     no  northwest    3866.8552     C
# ...    ...     ...     ...       ...    ...        ...          ...   ...
# 1335  18.0  female  36.850       0.0     no  southeast    1629.8335     B
# 1336  21.0  female  25.800       0.0     no  southwest     2007.945     D
# 1337  61.0  female  29.070       0.0    yes  northwest   29141.3603     C
# 1338   NaN     NaN     NaN       NaN    NaN        NaN          NaN   NaN
# 1339   NaN     NaN     NaN       NaN    NaN                           NaN
#
#       score
# 0      72.0
# 1      69.0
# 2      90.0
# 3      47.0
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# age         2
# sex         2
# bmi         2
# children    2
# smoker      2
# region      1
# charges     1
# Level       2
# score       2
# dtype: int64

# %%
df = df.dropna()

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# Level       0
# score       0
# dtype: int64

# %%
display (df)
# Out:
#        age     sex     bmi  children smoker     region      charges Level  \
# 0     19.0  female  27.900       0.0    yes  southwest    16884.924     B
# 1     18.0    male  33.770       1.0     no  southeast    1725.5523     C
# 2     28.0    male  33.000       3.0     no  southeast     4449.462     B
# 3     33.0    male  22.705       0.0     no  northwest  21984.47061     A
# 4     32.0    male  28.880       0.0     no  northwest    3866.8552     C
# ...    ...     ...     ...       ...    ...        ...          ...   ...
# 1333  50.0    male  30.970       3.0     no  northwest   10600.5483     B
# 1334  18.0  female  31.920       0.0     no  northeast    2205.9808     C
# 1335  18.0  female  36.850       0.0     no  southeast    1629.8335     B
# 1336  21.0  female  25.800       0.0     no  southwest     2007.945     D
# 1337  61.0  female  29.070       0.0    yes  northwest   29141.3603     C
#
#       score
# 0      72.0
# 1      69.0
# 2      90.0
# 3      47.0
# ...

# %%
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
sns.histplot(df['age'], kde=True, bins=5, color='skyblue')
plt.title('Distribution of Age')
# Out:
# Text(0.5, 1.0, 'Distribution of Age')

# %%
plt.subplot(1, 2, 2)
sns.histplot(df['charges'], kde=True, color='orange')
plt.title('Distribution of Charges')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x='sex', data=df, hue='sex', palette='pastel', legend=False)
plt.title('Count of Sex')
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x='region', data=df, hue='region', palette='muted', legend=False)
plt.title('Count of Region')
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.scatterplot(x='age', y='charges', hue='sex', data=df)
plt.title('Age vs. Charges by Sex')
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x='region', hue='sex', data=df, palette='muted')
plt.title('Count of Sex by Region')
plt.show()

# %%
print(df.dtypes)
# Out:
# age         float64
# sex          object
# bmi         float64
# children    float64
# smoker       object
# region       object
# charges      object
# Level        object
# score       float64
# dtype: object

# %%
df['charges'] = df['charges'].astype('float64')

# %%
from scipy.stats import ttest_ind

smokers = df[df['smoker'] == 'yes']['charges']
nonsmokers = df[df['smoker'] == 'no']['charges']

t_stat, p_value = ttest_ind(smokers, nonsmokers, equal_var=False)
print(f"T-statistic: {t_stat:.3f}, P-value: {p_value:.5f}")
# Out:
# T-statistic: 32.752, P-value: 0.00000

# %%
from scipy.stats import chi2_contingency

contingency_table = pd.crosstab(df['Level'], df['region'])
chi2, p, dof, expected = chi2_contingency(contingency_table)
print(f"Chi2: {chi2:.3f}, P-value: {p:.5f}")
# Out:
# Chi2: 13.933, P-value: 0.30498
