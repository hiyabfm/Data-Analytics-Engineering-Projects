# %%
# !jupyter nbconvert --to script Updated_final_project.ipynb
# Out:
# [NbConvertApp] Converting notebook Updated_final_project.ipynb to script
# [NbConvertApp] Writing 2272 bytes to Updated_final_project.py
